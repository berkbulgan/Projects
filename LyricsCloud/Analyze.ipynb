# %%
import pandas as pd
import numpy as np
f = open("Files/Adele.txt", "r")
x = []
y = []
for line in f:
    for word in line.split():
        if word.lower() in x:
            ind = x.index(word.lower())
            y[ind] = y[ind]+1
        else:
            x.append(word.lower())
            y.append(1)
f.close()
a = np.array(x)
b = np.array(y)
df = pd.DataFrame({"Word" : a, "Count" : b})
df.to_csv("Files/Adele.csv", index=False)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
f = open("test.txt", "r", encoding="utf-8")
text = f.read()
f.close()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

# %%
wordcloud = WordCloud(max_font_size=75, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
plt.savefig('adele.jpg')
wordcloud.to_file('N.png')

# %%
plt.savefig('adele.png')
